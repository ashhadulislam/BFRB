# %%
import pathlib
import pandas as pd
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import os
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import classification_report, f1_score
from detach_rocket.detach_classes import DetachEnsemble
import cebra
from cebra import CEBRA

import gc
import tempfile
from pathlib import Path

import pickle
from pathlib import Path

from sklearn.manifold import TSNE

import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization,
    LSTM, Bidirectional, GlobalAveragePooling1D
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import tensorflow as tf
import polars as pl
from sklearn.metrics import confusion_matrix

import numpy as np
from sktime.transformations.panel.rocket import MiniRocketMultivariate
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifierCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, f1_score

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix



import pickle
# Out:
# /Users/ashhadulislam/miniconda3/envs/py310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
def detach_rocket_results(train_embedding,y_train,val_embedding,y_val,plot=True,num_kernels=1000):
    X_train_rocket = train_embedding.transpose(0, 2, 1)
    X_val_rocket  = val_embedding.transpose(0, 2, 1)

    num_models = 5    
    DetachRocketEnsemble = DetachEnsemble(num_models=num_models, num_kernels=num_kernels)
    DetachRocketEnsemble.fit(X_train_rocket,y_train)
    y_val_pred = DetachRocketEnsemble.predict(X_val_rocket)

    cm = confusion_matrix(y_val, y_val_pred, labels=[0, 1])
    acc = accuracy_score(y_val, y_val_pred)
    prec = precision_score(y_val, y_val_pred, pos_label=1)   # precision for Target=1
    rec = recall_score(y_val, y_val_pred, pos_label=1)       # recall for Target=1

    if plot:

        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Normal (0)", "Target (1)"])
        disp.plot(cmap="Blues", values_format="d")
        plt.title("MiniRocket + Ridge Confusion Matrix (Validation)")
        plt.show()
        print(f"Accuracy : {acc:.4f}")
        print(f"Precision: {prec:.4f}")
        print(f"Recall   : {rec:.4f}")
        print("Macro F1:", f1_score(y_val, y_val_pred, average="macro"))
        print("Weighted F1:", f1_score(y_val, y_val_pred, average="weighted"))
        print("Confusion Matrix:\n", cm)


    return {
        "acc": acc,
        "precision": prec,
        "recall": rec,
        "macro_f1": f1_score(y_val, y_val_pred, average="macro"),
        "weighted_f1": f1_score(y_val, y_val_pred, average="weighted"),
        "cm": cm,
        #"y_val_pred": y_val_pred,
        #"model": minirocket_pipeline,
    }

# %%
TARGET_GESTURES = [
    'Above ear - pull hair',
    'Cheek - pinch skin',
    'Eyebrow - pull hair',
    'Eyelash - pull hair',
    'Forehead - pull hairline',
    'Forehead - scratch',
    'Neck - pinch skin',
    'Neck - scratch',
]

NON_TARGET_GESTURES = [
    'Write name on leg',
    'Wave hello',
    'Glasses on/off',
    'Text on phone',
    'Write name in air',
    'Feel around in tray and pull out an object',
    'Scratch knee/leg skin',
    'Pull air toward your face',
    'Drink from bottle/cup',
    'Pinch knee/leg skin',
]

ALL_GESTURES_SET = TARGET_GESTURES + NON_TARGET_GESTURES



gesture2idx = {g: i for i, g in enumerate(ALL_GESTURES_SET)}
idx2gesture = {i: g for g, i in gesture2idx.items()}
num_classes = len(ALL_GESTURES_SET)
print("Num gesture classes:", num_classes)
# Out:
# Num gesture classes: 18

# %%
df_cebra_res=pd.read_csv('res/cebra_feats.csv')

# %%
df_cebra_res
# Out:
#     drop_thermal_and_tof_options  use_raw_imus  use_physics_features  \
# 0                           True         False                  True
# 1                           True          True                 False
# 2                           True          True                  True
# 3                          False         False                 False
# 4                          False         False                  True
# 5                          False          True                 False
# 6                          False          True                  True
# 7                           True         False                  True
# 8                           True          True                 False
# 9                           True          True                  True
# 10                         False         False                 False
# 11                         False         False                  True
# 12                         False          True                 False
# 13                         False          True                  True
# 14                          True         False                  True
# 15                          True          True                 False
# 16                          True          True                  True
# 17                         False         False                 False
# 18                         False         False                  True
# 19                         False          True                 False
# 20                         False          True                  True
# 21                          True         False                  True
# 22                          True          True                 False
# 23                          True          True                  True
# 24                         False         False                 False
# 25                         False         False                  True
# 26                         False          True                 False
# 27                         False          True                  True
#
#     num_features  cebra_output_dims                   train_dist  \
# 0             24                  2  Counter({1: 4090, 0: 2430})
# 1             11                  2  Counter({1: 4090, 0: 2430})
# 2             31                  2  Counter({1: 4090, 0: 2430})
# 3            332                  2  Counter({1: 4090, 0: 2430})
# 4            349                  2  Counter({1: 4090, 0: 2430})
# 5            336                  2  Counter({1: 4090, 0: 2430})
# 6            356                  2  Counter({1: 4090, 0: 2430})
# 7             24                  8  Counter({1: 4090, 0: 2430})
# 8             11                  8  Counter({1: 4090, 0: 2430})
# 9             31                  8  Counter({1: 4090, 0: 2430})
# 10           332                  8  Counter({1: 4090, 0: 2430})
# 11           349                  8  Counter({1: 4090, 0: 2430})
# 12           336                  8  Counter({1: 4090, 0: 2430})
# 13           356                  8  Counter({1: 4090, 0: 2430})
# 14            24                 20  Counter({1: 4090, 0: 2430})
# 15            11                 20  Counter({1: 4090, 0: 2430})
# 16            31                 20  Counter({1: 4090, 0: 2430})
# 17           332                 20  Counter({1: 4090, 0: 2430})
# 18           349                 20  Counter({1: 4090, 0: 2430})
# 19           336                 20  Counter({1: 4090, 0: 2430})
# 20           356                 20  Counter({1: 4090, 0: 2430})
# 21            24                 32  Counter({1: 4090, 0: 2430})
# 22            11                 32  Counter({1: 4090, 0: 2430})
# 23            31                 32  Counter({1: 4090, 0: 2430})
# 24           332                 32  Counter({1: 4090, 0: 2430})
# 25           349                 32  Counter({1: 4090, 0: 2430})
# 26           336                 32  Counter({1: 4090, 0: 2430})
# 27           356                 32  Counter({1: 4090, 0: 2430})
#
#                       val_dist                    data_dist  \
# 0   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 1   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 2   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 3   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 4   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 5   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 6   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 7   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 8   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 9   Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 10  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 11  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 12  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 13  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 14  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 15  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 16  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 17  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 18  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 19  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 20  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 21  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 22  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 23  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 24  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 25  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 26  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
# 27  Counter({1: 1023, 0: 608})  Counter({1: 5113, 0: 3038})
#
#                             cebra_model_path
# 0    models/cebra_dtt_1_uri_0_uff_1_ced_2.pt
# 1    models/cebra_dtt_1_uri_1_uff_0_ced_2.pt
# 2    models/cebra_dtt_1_uri_1_uff_1_ced_2.pt
# 3    models/cebra_dtt_0_uri_0_uff_0_ced_2.pt
# 4    models/cebra_dtt_0_uri_0_uff_1_ced_2.pt
# 5    models/cebra_dtt_0_uri_1_uff_0_ced_2.pt
# 6    models/cebra_dtt_0_uri_1_uff_1_ced_2.pt
# 7    models/cebra_dtt_1_uri_0_uff_1_ced_8.pt
# 8    models/cebra_dtt_1_uri_1_uff_0_ced_8.pt
# 9    models/cebra_dtt_1_uri_1_uff_1_ced_8.pt
# 10   models/cebra_dtt_0_uri_0_uff_0_ced_8.pt
# 11   models/cebra_dtt_0_uri_0_uff_1_ced_8.pt
# 12   models/cebra_dtt_0_uri_1_uff_0_ced_8.pt
# 13   models/cebra_dtt_0_uri_1_uff_1_ced_8.pt
# 14  models/cebra_dtt_1_uri_0_uff_1_ced_20.pt
# 15  models/cebra_dtt_1_uri_1_uff_0_ced_20.pt
# 16  models/cebra_dtt_1_uri_1_uff_1_ced_20.pt
# 17  models/cebra_dtt_0_uri_0_uff_0_ced_20.pt
# 18  models/cebra_dtt_0_uri_0_uff_1_ced_20.pt
# 19  models/cebra_dtt_0_uri_1_uff_0_ced_20.pt
# 20  models/cebra_dtt_0_uri_1_uff_1_ced_20.pt
# 21  models/cebra_dtt_1_uri_0_uff_1_ced_32.pt
# 22  models/cebra_dtt_1_uri_1_uff_0_ced_32.pt
# 23  models/cebra_dtt_1_uri_1_uff_1_ced_32.pt
# 24  models/cebra_dtt_0_uri_0_uff_0_ced_32.pt
# 25  models/cebra_dtt_0_uri_0_uff_1_ced_32.pt
# 26  models/cebra_dtt_0_uri_1_uff_0_ced_32.pt
# 27  models/cebra_dtt_0_uri_1_uff_1_ced_32.pt

# %%
drop_thermal_and_tof_options=[True,False]
use_raw_imus_options=[False,True]
use_physics_features_options=[False,True]
cebra_output_dims_list=[2,8,20,32]
num_kernels_list=[500,10000,5000,1000]

classifxn_res=[]

for cebra_output_dims in cebra_output_dims_list:
    for drop_thermal_and_tof in drop_thermal_and_tof_options:
        for use_raw_imus in use_raw_imus_options:
            for use_physics_features in use_physics_features_options:
                if drop_thermal_and_tof and not use_physics_features and not use_raw_imus:
                    continue

                scenario_key=f'dtt={int(drop_thermal_and_tof)}_uri={int(use_raw_imus)}_uff={int(use_physics_features)}_ced={int(cebra_output_dims)}'
                print(scenario_key)


                with open("res/all_splits.pkl", "rb") as f:                    
                    splits_store = pickle.load(f)

                              
                if scenario_key not in splits_store:
                    del splits_store                
                    gc.collect()
                    continue
                
                X_train = splits_store[scenario_key]["X_train"]
                y_train = splits_store[scenario_key]["y_train"]
                X_val   = splits_store[scenario_key]["X_val"]
                y_val   = splits_store[scenario_key]["y_val"]
                del splits_store                
                gc.collect()

                print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
                X_train_flat = X_train.reshape(-1, X_train.shape[-1])
                X_val_flat   = X_val.reshape(-1, X_val.shape[-1])
                # read the model
                model_path=f'models/cebra_dtt_{int(drop_thermal_and_tof)}_uri_{int(use_raw_imus)}_uff_{int(use_physics_features)}_ced_{int(cebra_output_dims)}.pt'
                loaded_cebra_model = cebra.CEBRA.load(model_path)
                val_embedding_flat = loaded_cebra_model.transform(X_val_flat)
                train_embedding_flat = loaded_cebra_model.transform(X_train_flat)

                train_embedding = train_embedding_flat.reshape(
                    X_train.shape[0],   # 6520 trials
                    X_train.shape[1],   # 103 time steps
                    -1                  # latent dim (8)
                )

                val_embedding = val_embedding_flat.reshape(
                    X_val.shape[0],
                    X_val.shape[1],
                    -1
                )

                train_means = train_embedding.mean(axis=1)
                val_means = val_embedding.mean(axis=1)

                for num_kernels in num_kernels_list:

                    dr_results=detach_rocket_results(train_embedding,y_train,val_embedding,y_val,plot=False,
                                                     num_kernels=num_kernels)                
                    

                    res_dic={
                        'drop_thermal_and_tof_options':drop_thermal_and_tof,
                        'use_raw_imus':use_raw_imus,
                        'use_physics_features':use_physics_features,
                        'num_features':X_train.shape[-1],
                        'cebra_output_dims':cebra_output_dims,
                        'train_dist':Counter(y_train),
                        'val_dist':Counter(y_val),   
                        'num_kernels':num_kernels,
                        **dr_results,
                        }
                    classifxn_res.append(res_dic)
                    classifxn_res_df=pd.DataFrame(classifxn_res)
                    classifxn_res_df.to_csv('res/dr_classifxn.csv',index=False)
# Out:
# dtt=1_uri=0_uff=1_ced=2
# (6520, 103, 24) (6520,) (1631, 103, 24) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.21%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.09%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.48%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.99%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.40%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.76%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.81%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 78.01%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.48%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.98%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.64%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.55%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 88.02%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.91%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.73%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.97%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.78%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.20%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.99%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.18%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.23%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.89%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.57%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 82.12%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 85.06%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.89%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.54%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 85.55%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.71%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.64%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.70%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 80.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.36%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 81.18%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.14%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.01%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.87%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 80.08%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 82.79%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.58%
# -------------------------
# dtt=1_uri=1_uff=0_ced=2
# (6520, 103, 11) (6520,) (1631, 103, 11) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.58%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.69%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.38%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.37%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.06%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.23%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.27%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.31%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.26%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.15%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.48%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.79%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.29%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.34%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.74%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.45%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.53%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.80%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 75.34%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.48%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.90%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.27%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.95%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.60%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.26%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.65%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.91%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.80%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 76.26%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.97%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.64%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 76.60%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.20%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.80%
# -------------------------
# dtt=1_uri=1_uff=1_ced=2
# (6520, 103, 31) (6520,) (1631, 103, 31) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 81.26%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 78.87%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.90%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 80.12%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.61%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 78.76%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 81.23%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 79.49%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.95%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 78.36%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.50%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.03%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.84%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.63%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.42%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.06%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.38%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.68%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 87.67%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.39%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.46%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.36%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.83%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.87%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.86%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.16%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.57%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.49%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.88%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.22%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.02%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.03%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.67%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.18%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.71%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.16%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.84%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.15%
# -------------------------
# dtt=0_uri=0_uff=0_ced=2
# (6520, 103, 332) (6520,) (1631, 103, 332) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.83%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.50%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.33%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.04%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.33%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 78.07%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 78.76%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 76.83%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 77.71%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.25%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 82.55%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.23%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.89%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.17%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.31%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.19%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.09%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.23%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.25%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.78%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.01%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 82.06%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.30%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.92%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.29%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 82.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.53%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.95%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.93%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 78.83%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.91%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 78.34%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.78%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 78.51%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.84%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 78.56%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.45%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 78.62%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.84%
# -------------------------
# dtt=0_uri=0_uff=1_ced=2
# (6520, 103, 349) (6520,) (1631, 103, 349) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.95%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 79.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 79.49%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.44%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 80.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 79.39%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 79.25%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.97%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 79.46%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.83%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 85.66%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 82.73%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 54555.95
# Train Accuraccy Full ROCKET: 80.81%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.56%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 54555.95
# Train Accuraccy Full ROCKET: 80.66%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 54555.95
# Train Accuraccy Full ROCKET: 80.66%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.72%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 85.64%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 85.92%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.53%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 82.45%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.28%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.07%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.50%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.26%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.37%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.70%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.57%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 82.13%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.09%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.43%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.05%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.36%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 79.88%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.51%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.09%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.11%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.97%
# -------------------------
# dtt=0_uri=1_uff=0_ced=2
# (6520, 103, 336) (6520,) (1631, 103, 336) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.22%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.49%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 76.64%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.54%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.30%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.88%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.04%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.92%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 76.81%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 74.46%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.42%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.08%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.75%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.53%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.39%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.67%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.87%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.36%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.94%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.84%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.23%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.00%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.91%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.57%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.28%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.40%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.96%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.61%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 80.29%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 76.13%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 75.05%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 76.07%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 74.71%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 79.80%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.87%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 75.98%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 74.29%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 76.03%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 75.71%
# -------------------------
# dtt=0_uri=1_uff=1_ced=2
# (6520, 103, 356) (6520,) (1631, 103, 356) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.47%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.43%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 78.22%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 78.14%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.21%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 77.61%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 76.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 78.08%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 75.32%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.70%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.50%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.62%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.74%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.82%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.74%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.80%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 83.94%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 81.04%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.89%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.70%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 80.94%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 79.63%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.09%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.45%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 81.18%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 78.96%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 77.41%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 77.21%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 77.50%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 77.32%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 76.10%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 77.15%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 75.66%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 77.13%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 75.81%
# -------------------------
# dtt=1_uri=0_uff=1_ced=8
# (6520, 103, 24) (6520,) (1631, 103, 24) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.60%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.88%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.11%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.82%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.90%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.06%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.00%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.85%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.82%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.93%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 93.27%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.83%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.15%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.65%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.10%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.96%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.32%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 91.09%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.03%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.77%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.25%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.84%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.01%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 91.07%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.37%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.81%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.88%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.48%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.56%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.19%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 85.26%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.39%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.40%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.45%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 87.04%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.04%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.29%
# -------------------------
# dtt=1_uri=1_uff=0_ced=8
# (6520, 103, 11) (6520,) (1631, 103, 11) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 82.39%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 81.23%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 82.87%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 81.50%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 83.25%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 81.35%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 82.36%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 80.32%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 82.32%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 79.00%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 91.87%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.27%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.02%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.33%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.19%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.07%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.13%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.37%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 91.60%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.32%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 89.14%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.35%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 88.68%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.10%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 88.74%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.13%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 88.33%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.89%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 89.02%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 86.70%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.78%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.47%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.84%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.58%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 81.67%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.86%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.36%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.72%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.96%
# -------------------------
# dtt=1_uri=1_uff=1_ced=8
# (6520, 103, 31) (6520,) (1631, 103, 31) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.29%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.44%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.28%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.17%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.32%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.18%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.14%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.27%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.78%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.65%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# ...
# Train Accuraccy Full ROCKET: 84.51%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.42%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 85.12%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 84.37%
# -------------------------
# dtt=0_uri=0_uff=1_ced=32
# (6520, 103, 349) (6520,) (1631, 103, 349) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.06%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.10%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.90%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.98%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.87%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.74%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.73%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.76%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.94%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 93.90%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 95.02%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 93.65%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.88%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.05%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 95.15%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.36%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.82%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.07%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.38%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.43%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.50%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.10%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.41%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.52%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.33%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.04%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.47%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.28%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.57%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 88.02%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.38%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 86.73%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.15%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.91%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.55%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 87.32%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.14%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.68%
# -------------------------
# dtt=0_uri=1_uff=0_ced=32
# (6520, 103, 336) (6520,) (1631, 103, 336) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.66%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.10%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.71%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 82.04%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.97%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.25%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 85.00%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.02%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 84.56%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.01%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.37%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.16%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.31%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.84%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.11%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.64%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.87%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.80%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 93.19%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.24%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 89.85%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.42%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.05%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 87.65%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.08%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.90%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 89.79%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 90.09%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.57%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.79%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.46%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 84.59%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 83.99%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 88.04%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.48%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.94%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.49%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.68%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.52%
# -------------------------
# dtt=0_uri=1_uff=1_ced=32
# (6520, 103, 356) (6520,) (1631, 103, 356) (1631,)
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.75%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.42%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.83%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.62%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 86.89%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 83.65%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.90%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 85.21%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 87.88%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 84.51%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.92%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.96%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.72%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 93.59%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.59%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 94.23%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 94.62%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.27%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 95.06%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 93.67%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.22%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.89%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.29%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 90.11%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.29%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 89.06%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.06%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 92.13%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 4832.93
# Train Accuraccy Full ROCKET: 92.32%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 91.30%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 89.85%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 86.47%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.46%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 87.65%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.43%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 88.76%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.32%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 86.07%
# -------------------------
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 428.13
# Train Accuraccy Full ROCKET: 90.52%
# -------------------------
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 428.13
# Train Accuraccy Detach Model: 88.31%
# -------------------------
